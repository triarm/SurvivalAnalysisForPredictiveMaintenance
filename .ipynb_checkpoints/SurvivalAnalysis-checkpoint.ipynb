# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc = {'figure.figsize':(16,9)})

# %%
column1 = ["machine_name", "cycle", "operational_setting_1", "operational_setting_2", "operational_setting_3"]
column2 = [f'sensor_measurement_{i:02}' for i in range(1,22)]
columns = column1 + column2

# %%
turbofan_df = pd.read_csv("dataset/train_FD001.txt", header = None, sep = "\s+", names = columns)
turbofan_df.head()
# Out:
#    machine_name  cycle  operational_setting_1  operational_setting_2  \
# 0             1      1                -0.0007                -0.0004
# 1             1      2                 0.0019                -0.0003
# 2             1      3                -0.0043                 0.0003
# 3             1      4                 0.0007                 0.0000
# 4             1      5                -0.0019                -0.0002
#
#    operational_setting_3  sensor_measurement_01  sensor_measurement_02  \
# 0                  100.0                 518.67                 641.82
# 1                  100.0                 518.67                 642.15
# 2                  100.0                 518.67                 642.35
# 3                  100.0                 518.67                 642.35
# 4                  100.0                 518.67                 642.37
#
#    sensor_measurement_03  sensor_measurement_04  sensor_measurement_05  ...  \
# 0                1589.70                1400.60                  14.62  ...
# 1                1591.82                1403.14                  14.62  ...
# 2                1587.99                1404.20                  14.62  ...
# 3                1582.79                1401.87                  14.62  ...
# 4                1582.85                1406.22                  14.62  ...
#
#    sensor_measurement_12  sensor_measurement_13  sensor_measurement_14  \
# 0                 521.66                2388.02                8138.62
# 1                 522.28                2388.07                8131.49
# 2                 522.42                2388.03                8133.23
# 3                 522.86                2388.08                8133.83
# 4                 522.19                2388.04                8133.80
#
#    sensor_measurement_15  sensor_measurement_16  sensor_measurement_17  \
# 0                 8.4195                   0.03                    392
# 1                 8.4318                   0.03                    392
# 2                 8.4178                   0.03                    390
# 3                 8.3682                   0.03                    392
# 4                 8.4294                   0.03                    393
#
#    sensor_measurement_18  sensor_measurement_19  sensor_measurement_20  \
# 0                   2388                  100.0                  39.06
# 1                   2388                  100.0                  39.00
# 2                   2388                  100.0                  38.95
# 3                   2388                  100.0                  38.88
# 4                   2388                  100.0                  38.90
#
#    sensor_measurement_21
# 0                23.4190
# 1                23.4236
# 2                23.3442
# 3                23.3739
# 4                23.4044
#
# [5 rows x 26 columns]

# %%
max_cycle = turbofan_df.groupby(by = "machine_name")['cycle'].transform(max)
turbofan_df = turbofan_df[turbofan_df["cycle"] == max_cycle]
turbofan_df.head()
# Out:
#       machine_name  cycle  operational_setting_1  operational_setting_2  \
# 191              1    192                 0.0009                -0.0000
# 478              2    287                -0.0005                 0.0006
# 657              3    179                 0.0012                 0.0000
# 846              4    189                -0.0024                -0.0002
# 1115             5    269                 0.0022                 0.0003
#
#       operational_setting_3  sensor_measurement_01  sensor_measurement_02  \
# 191                   100.0                 518.67                 643.54
# 478                   100.0                 518.67                 643.85
# 657                   100.0                 518.67                 643.51
# 846                   100.0                 518.67                 644.53
# 1115                  100.0                 518.67                 643.46
#
#       sensor_measurement_03  sensor_measurement_04  sensor_measurement_05  \
# 191                 1601.41                1427.20                  14.62
# 478                 1608.50                1430.84                  14.62
# 657                 1604.80                1428.23                  14.62
# 846                 1612.11                1432.55                  14.62
# 1115                1597.28                1430.74                  14.62
#
#       ...  sensor_measurement_12  sensor_measurement_13  \
# 191   ...                 520.08                2388.32
# 478   ...                 519.81                2388.21
# 657   ...                 519.53                2388.20
# 846   ...                 519.84                2388.16
# 1115  ...                 519.86                2388.16
#
#       sensor_measurement_14  sensor_measurement_15  sensor_measurement_16  \
# 191                 8110.93                 8.5113                   0.03
# 478                 8175.57                 8.5365                   0.03
# 657                 8255.34                 8.5056                   0.03
# 846                 8259.42                 8.5246                   0.03
# 1115                8212.75                 8.5209                   0.03
#
#       sensor_measurement_17  sensor_measurement_18  sensor_measurement_19  \
# 191                     396                   2388                  100.0
# 478                     398                   2388                  100.0
# 657                     398                   2388                  100.0
# 846                     398                   2388                  100.0
# 1115                    397                   2388                  100.0
#
#       sensor_measurement_20  sensor_measurement_21
# 191                   38.48                22.9649
# 478                   38.43                23.0848
# 657                   38.40                22.9562
# 846                   38.44                23.1006
# 1115                  38.45                23.0296
#
# [5 rows x 26 columns]

# %%
plt.hlines(y=turbofan_df['machine_name'], xmin=1, xmax=turbofan_df['cycle'], color='skyblue')
plt.plot(turbofan_df['cycle'], turbofan_df['machine_name'], "o")
plt.plot([1 for i in range(len(turbofan_df))], turbofan_df['machine_name'], "o")

# Add titles and axis names
plt.title("Max. Cycle")
plt.xlabel('Cycle')
plt.ylabel('Machine ID')

# Show the plot
plt.show()

# %%
deleted_columns = list(turbofan_df.loc[:, (turbofan_df.nunique() == 1)].columns)
deleted_columns.append('sensor_measurement_17')
deleted_columns.append('operational_setting_2')

# %%
deleted_columns = sorted(deleted_columns)
deleted_columns
# Out:
# ['operational_setting_2',
#  'operational_setting_3',
#  'sensor_measurement_01',
#  'sensor_measurement_05',
#  'sensor_measurement_06',
#  'sensor_measurement_10',
#  'sensor_measurement_16',
#  'sensor_measurement_17',
#  'sensor_measurement_18',
#  'sensor_measurement_19']

# %%
turbofan_df = turbofan_df[turbofan_df.columns[~turbofan_df.columns.isin(deleted_columns)]]

# %%
# turbofan_df['cycle'] = turbofan_df['cycle'].apply(lambda x: x if x < 220 else 220)
turbofan_df['status'] = turbofan_df['cycle'].apply(lambda x: False if x > 220 else True)

# %%
turbofan_df
# Out:
#        machine_name  cycle  operational_setting_1  sensor_measurement_02  \
# 191               1    192                 0.0009                 643.54
# 478               2    287                -0.0005                 643.85
# 657               3    179                 0.0012                 643.51
# 846               4    189                -0.0024                 644.53
# 1115              5    269                 0.0022                 643.46
# ...             ...    ...                    ...                    ...
# 19887            96    336                -0.0031                 643.74
# 20089            97    202                 0.0014                 643.79
# 20245            98    156                 0.0077                 643.02
# 20430            99    185                -0.0019                 643.93
# 20630           100    200                -0.0032                 643.85
#
#        sensor_measurement_03  sensor_measurement_04  sensor_measurement_07  \
# 191                  1601.41                1427.20                 551.25
# 478                  1608.50                1430.84                 551.66
# 657                  1604.80                1428.23                 551.91
# 846                  1612.11                1432.55                 551.93
# 1115                 1597.28                1430.74                 550.77
# ...                      ...                    ...                    ...
# 19887                1599.20                1432.12                 550.78
# 20089                1610.66                1427.41                 551.55
# 20245                1603.77                1432.16                 551.52
# 20430                1598.42                1421.56                 550.64
# 20630                1600.38                1432.14                 550.79
#
#        sensor_measurement_08  sensor_measurement_09  sensor_measurement_11  \
# 191                  2388.32                9033.22                  48.25
# 478                  2388.20                9109.36                  48.12
# 657                  2388.14                9197.52                  48.09
# 846                  2388.13                9198.32                  48.15
# 1115                 2388.18                9157.05                  48.26
# ...                      ...                    ...                    ...
# 19887                2388.28                9075.64                  48.17
# 20089                2388.15                9208.02                  47.94
# 20245                2388.24                9058.54                  48.29
# 20430                2388.29                9050.61                  48.29
# 20630                2388.26                9061.48                  48.20
#
#        sensor_measurement_12  sensor_measurement_13  sensor_measurement_14  \
# 191                   520.08                2388.32                8110.93
# 478                   519.81                2388.21                8175.57
# 657                   519.53                2388.20                8255.34
# 846                   519.84                2388.16                8259.42
# 1115                  519.86                2388.16                8212.75
# ...                      ...                    ...                    ...
# 19887                 519.18                2388.24                8144.03
# 20089                 519.91                2388.15                8263.63
# 20245                 519.55                2388.26                8122.22
# 20430                 519.99                2388.24                8127.53
# 20630                 519.30                2388.26                8137.33
#
#        sensor_measurement_15  sensor_measurement_20  sensor_measurement_21  \
# 191                   8.5113                  38.48                22.9649
# 478                   8.5365                  38.43                23.0848
# 657                   8.5056                  38.40                22.9562
# 846                   8.5246                  38.44                23.1006
# 1115                  8.5209                  38.45                23.0296
# ...                      ...                    ...                    ...
# 19887                 8.5022                  38.36                23.0258
# 20089                 8.5277                  38.29                23.1184
# 20245                 8.5308                  38.33                23.1137
# 20430                 8.5425                  38.49                23.1931
# 20630                 8.5036                  38.37                23.0522
#
#        status
# 191      True
# 478     False
# 657      True
# 846      True
# 1115    False
# ...       ...
# 19887   False
# 20089    True
# 20245    True
# 20430    True
# 20630    True
#
# [100 rows x 17 columns]

# %%
from sksurv.nonparametric import kaplan_meier_estimator

time, survival_prob = kaplan_meier_estimator(turbofan_df["status"], turbofan_df["cycle"])
time, survival_prob = np.append(0, time), np.append(1, survival_prob)
plt.step(time, survival_prob, where = "post")
plt.xlim(left = 0, right = 220)
plt.title("Kaplan Meier Estimator")
plt.ylabel("est. probability of survival $\hat{S}(t)$")
plt.xlabel("time $t$")
# Out:
# Text(0.5, 0, 'time $t$')

# %%
data_x = turbofan_df.iloc[:, 2:16]
data_y = turbofan_df.iloc[:, [16,1]]
data_y = list(data_y.itertuples(index = None, name = None))
data_y = np.array(data_y, dtype=[('status', bool), ('cycle', int)])

# %%
data_y
# Out:
# array([( True, 192), (False, 287), ( True, 179), ( True, 189),
#        (False, 269), ( True, 188), (False, 259), ( True, 150),
#        ( True, 201), (False, 222), (False, 240), ( True, 170),
#        ( True, 163), ( True, 180), ( True, 207), ( True, 209),
#        (False, 276), ( True, 195), ( True, 158), (False, 234),
#        ( True, 195), ( True, 202), ( True, 168), ( True, 147),
#        (False, 230), ( True, 199), ( True, 156), ( True, 165),
#        ( True, 163), ( True, 194), (False, 234), ( True, 191),
#        ( True, 200), ( True, 195), ( True, 181), ( True, 158),
#        ( True, 170), ( True, 194), ( True, 128), ( True, 188),
#        ( True, 216), ( True, 196), ( True, 207), ( True, 192),
#        ( True, 158), (False, 256), ( True, 214), (False, 231),
#        ( True, 215), ( True, 198), ( True, 213), ( True, 213),
#        ( True, 195), (False, 257), ( True, 193), (False, 275),
#        ( True, 137), ( True, 147), (False, 231), ( True, 172),
#        ( True, 185), ( True, 180), ( True, 174), (False, 283),
#        ( True, 153), ( True, 202), (False, 313), ( True, 199),
#        (False, 362), ( True, 137), ( True, 208), ( True, 213),
#        ( True, 213), ( True, 166), (False, 229), ( True, 210),
#        ( True, 154), (False, 231), ( True, 199), ( True, 185),
#        (False, 240), ( True, 214), (False, 293), (False, 267),
#        ( True, 188), (False, 278), ( True, 178), ( True, 213),
#        ( True, 217), ( True, 154), ( True, 135), (False, 341),
#        ( True, 155), (False, 258), (False, 283), (False, 336),
#        ( True, 202), ( True, 156), ( True, 185), ( True, 200)],
#       dtype=[('status', '?'), ('cycle', '<i4')])

# %%
sns.heatmap(data_x.corr(), annot = True,)
# Out:
# <AxesSubplot:>

# %%
from sksurv.linear_model import CoxPHSurvivalAnalysis

estimator = CoxPHSurvivalAnalysis(verbose = 10, alpha = 1e-5)
estimator.fit(data_x, data_y)
# Out:
# iter      1: update = [ 1.59428475e+01  4.50579327e-01 -3.17141136e-02 -6.28390035e-02
#   3.25876945e-01  2.69486183e+00  8.78152256e-04 -1.31672298e+00
#  -5.09329155e-03 -4.79249277e+00  1.39552667e-04 -1.57479933e+01
#   7.22128283e-01  6.61368537e-01]
# iter      1: loss = inf
# C:\Users\HP\anaconda3\lib\site-packages\sksurv\linear_model\coxph.py:174: RuntimeWarning: overflow encountered in exp
#   risk_set += numpy.exp(xw[k])
# C:\Users\HP\anaconda3\lib\site-packages\sksurv\linear_model\coxph.py:171: RuntimeWarning: overflow encountered in exp
#   risk_set2 += numpy.exp(xw[k])
# C:\Users\HP\anaconda3\lib\site-packages\sksurv\linear_model\coxph.py:453: RuntimeWarning: invalid value encountered in double_scalars
#   res = numpy.abs(1 - (loss_new / loss))
# C:\Users\HP\anaconda3\lib\site-packages\sksurv\linear_model\coxph.py:195: RuntimeWarning: overflow encountered in exp
#   exp_xw = numpy.exp(offset + numpy.dot(x, w))
# C:\Users\HP\anaconda3\lib\site-packages\sksurv\linear_model\coxph.py:229: RuntimeWarning: invalid value encountered in multiply
#   risk_set_x += exp_xw[k] * xk
# C:\Users\HP\anaconda3\lib\site-packages\sksurv\linear_model\coxph.py:230: RuntimeWarning: invalid value encountered in multiply
#   risk_set_xx += exp_xw[k] * xx
# C:\Users\HP\anaconda3\lib\site-packages\sksurv\linear_model\coxph.py:239: RuntimeWarning: invalid value encountered in true_divide
#   z = risk_set_x / risk_set
# C:\Users\HP\anaconda3\lib\site-packages\sksurv\linear_model\coxph.py:242: RuntimeWarning: invalid value encountered in true_divide
#   a = risk_set_xx / risk_set
# C:\Users\HP\anaconda3\lib\site-packages\sksurv\linear_model\coxph.py:224: RuntimeWarning: invalid value encountered in add
#   risk_set_x2 += exp_xw[k] * xk
# C:\Users\HP\anaconda3\lib\site-packages\sksurv\linear_model\coxph.py:225: RuntimeWarning: invalid value encountered in add
#   risk_set_xx2 += exp_xw[k] * xx
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20052/1879847990.py in <module>
#       2
#       3 estimator = CoxPHSurvivalAnalysis(verbose = 10, alpha = 1e-5)
# ----> 4 estimator.fit(data_x, data_y)
#
# ~\anaconda3\lib\site-packages\sksurv\linear_model\coxph.py in fit(self, X, y)
#     435
#     436             if not numpy.all(numpy.isfinite(delta)):
# --> 437                 raise ValueError("search direction contains NaN or infinite values")
#     438
#     439             w_new = w - delta
#
# ValueError: search direction contains NaN or infinite values
